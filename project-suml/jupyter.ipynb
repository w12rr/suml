# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
# using the Csv file 
df = pd.read_csv('Car_sale_ads_short.csv')  
  
# Checking the first 5 entries of dataset 
df.head()
# Out:
#    Index  Price Currency Condition Vehicle_brand Vehicle_model  \
# 0      0  86200      PLN       New        Abarth           595
# 1      1  43500      PLN      Used        Abarth         Other
# 2      2  44900      PLN      Used        Abarth           500
# 3      3  39900      PLN      Used        Abarth           500
# 4      4  97900      PLN       New        Abarth           595
#
#   Vehicle_version  Vehicle_generation  Production_year  Mileage_km  ...  \
# 0             NaN                 NaN             2021         1.0  ...
# 1             NaN                 NaN             1974     59000.0  ...
# 2             NaN                 NaN             2018     52000.0  ...
# 3             NaN                 NaN             2012     29000.0  ...
# 4             NaN                 NaN             2021       600.0  ...
#
#    Transmission        Type Doors_number  Colour Origin_country First_owner  \
# 0        Manual  small_cars          3.0    gray            NaN         NaN
# 1        Manual       coupe          2.0  silver            NaN         NaN
# 2     Automatic  small_cars          3.0  silver            NaN         NaN
# 3        Manual  small_cars          3.0    gray            NaN         NaN
# 4        Manual  small_cars          3.0    blue            NaN         NaN
#
#   First_registration_date  Offer_publication_date  \
# 0                     NaN              04/05/2021
# 1                     NaN              03/05/2021
# 2                     NaN              03/05/2021
# 3                     NaN              30/04/2021
# 4                     NaN              30/04/2021
#
#                                       Offer_location  \
# 0  ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 1  kanonierska12 - 04-425 Warszawa, Rembertów (Po...
# 2                   Warszawa, Mazowieckie, Białołęka
# 3                                  Jaworzno, Śląskie
# 4  ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
#
#                                             Features
# 0                                                 []
# 1                                                 []
# 2  ['ABS', 'Electric front windows', 'Drivers air...
# 3  ['ABS', 'Electric front windows', 'Drivers air...
# 4  ['ABS', 'Electrically adjustable mirrors', 'Pa...
#
# [5 rows x 25 columns]

# %%
headers = ["Index","Price","Currency","Condition","Vehicle_brand","Vehicle_model","Vehicle_version","Vehicle_generation","Production_year","Mileage_km","Power_HP","Displacement_cm3","Fuel_type","CO2_emissions","Drive","Transmission","Type","Doors_number","Colour","Origin_country","First_owner","First_registration_date","Offer_publication_date","Offer_location","Features"] 
  
df.columns=headers 
df.head()
# Out:
#    Index  Price Currency Condition Vehicle_brand Vehicle_model  \
# 0      0  86200      PLN       New        Abarth           595
# 1      1  43500      PLN      Used        Abarth         Other
# 2      2  44900      PLN      Used        Abarth           500
# 3      3  39900      PLN      Used        Abarth           500
# 4      4  97900      PLN       New        Abarth           595
#
#   Vehicle_version  Vehicle_generation  Production_year  Mileage_km  ...  \
# 0             NaN                 NaN             2021         1.0  ...
# 1             NaN                 NaN             1974     59000.0  ...
# 2             NaN                 NaN             2018     52000.0  ...
# 3             NaN                 NaN             2012     29000.0  ...
# 4             NaN                 NaN             2021       600.0  ...
#
#    Transmission        Type Doors_number  Colour Origin_country First_owner  \
# 0        Manual  small_cars          3.0    gray            NaN         NaN
# 1        Manual       coupe          2.0  silver            NaN         NaN
# 2     Automatic  small_cars          3.0  silver            NaN         NaN
# 3        Manual  small_cars          3.0    gray            NaN         NaN
# 4        Manual  small_cars          3.0    blue            NaN         NaN
#
#   First_registration_date  Offer_publication_date  \
# 0                     NaN              04/05/2021
# 1                     NaN              03/05/2021
# 2                     NaN              03/05/2021
# 3                     NaN              30/04/2021
# 4                     NaN              30/04/2021
#
#                                       Offer_location  \
# 0  ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 1  kanonierska12 - 04-425 Warszawa, Rembertów (Po...
# 2                   Warszawa, Mazowieckie, Białołęka
# 3                                  Jaworzno, Śląskie
# 4  ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
#
#                                             Features
# 0                                                 []
# 1                                                 []
# 2  ['ABS', 'Electric front windows', 'Drivers air...
# 3  ['ABS', 'Electric front windows', 'Drivers air...
# 4  ['ABS', 'Electrically adjustable mirrors', 'Pa...
#
# [5 rows x 25 columns]

# %%
data = df 
  
# Finding the missing values 
data.isna().any() 
  
# Finding if missing values  
data.isnull().any()
# Out:
# Index                      False
# Price                      False
# Currency                   False
# Condition                  False
# Vehicle_brand              False
# Vehicle_model              False
# Vehicle_version             True
# Vehicle_generation          True
# Production_year            False
# Mileage_km                  True
# Power_HP                    True
# Displacement_cm3            True
# Fuel_type                  False
# CO2_emissions               True
# Drive                       True
# Transmission                True
# Type                       False
# Doors_number                True
# Colour                     False
# Origin_country              True
# First_owner                 True
# First_registration_date     True
# Offer_publication_date     False
# Offer_location             False
# Features                   False
# dtype: bool

# %%
print(data.columns) 
  
# checking the data type of each column 
data.dtypes 
data.head(20)
# Out:
# Index(['Index', 'Price', 'Currency', 'Condition', 'Vehicle_brand',
#        'Vehicle_model', 'Vehicle_version', 'Vehicle_generation',
#        'Production_year', 'Mileage_km', 'Power_HP', 'Displacement_cm3',
#        'Fuel_type', 'CO2_emissions', 'Drive', 'Transmission', 'Type',
#        'Doors_number', 'Colour', 'Origin_country', 'First_owner',
#        'First_registration_date', 'Offer_publication_date', 'Offer_location',
#        'Features', 'date', 'Offer_publication_date_as_date'],
#       dtype='object')
#     Index   Price Currency Condition Vehicle_brand Vehicle_model  \
# 0       0   86200      PLN       New        Abarth           595
# 1       1   43500      PLN      Used        Abarth         Other
# 2       2   44900      PLN      Used        Abarth           500
# 3       3   39900      PLN      Used        Abarth           500
# 4       4   97900      PLN       New        Abarth           595
# 5       5   62950      PLN      Used        Abarth           595
# 6       6   69900      PLN      Used        Abarth           595
# 7       7   69900      PLN      Used        Abarth           500
# 8       8  120750      PLN       New        Abarth           595
# 9       9   93100      PLN       New        Abarth           595
# 10     10   67000      PLN      Used        Abarth           595
# 11     11   31900      PLN      Used        Abarth  Grande Punto
# 12     12   70000      PLN      Used        Abarth           595
# 13     13   38500      PLN      Used        Abarth           500
# 14     14   41400      PLN      Used        Abarth           500
# 15     15   36000      PLN      Used        Abarth         Other
# 16     16   80900      PLN       New        Abarth           595
# 17     17  127921      PLN       New        Abarth           595
# 18     18   70900      PLN      Used        Abarth           595
# 19     19   22900      PLN      Used        Abarth  Grande Punto
#
#    Vehicle_version  Vehicle_generation  Production_year  Mileage_km  ...  \
# 0              NaN                 NaN             2021         1.0  ...
# 1              NaN                 NaN             1974     59000.0  ...
# 2              NaN                 NaN             2018     52000.0  ...
# 3              NaN                 NaN             2012     29000.0  ...
# 4              NaN                 NaN             2021       600.0  ...
# 5              NaN                 NaN             2016     46060.0  ...
# 6              NaN                 NaN             2021      2900.0  ...
# 7              NaN                 NaN             2019     20000.0  ...
# 8              NaN                 NaN             2021         1.0  ...
# 9              NaN                 NaN             2021         1.0  ...
# 10             NaN                 NaN             2018     38000.0  ...
# 11             NaN                 NaN             2010    179000.0  ...
# 12             NaN                 NaN             2017     18470.0  ...
# 13             NaN                 NaN             2015    117000.0  ...
# 14             NaN                 NaN             2014     79233.0  ...
# 15             NaN                 NaN             2012     82000.0  ...
# 16             NaN                 NaN             2020         1.0  ...
# 17             NaN                 NaN             2021         3.0  ...
# 18             NaN                 NaN             2019     11000.0  ...
# 19             NaN                 NaN             2009    182000.0  ...
#
#     Doors_number  Colour Origin_country  First_owner First_registration_date  \
# 0            3.0    gray            NaN          NaN                     NaN
# 1            2.0  silver            NaN          NaN                     NaN
# 2            3.0  silver            NaN          NaN                     NaN
# 3            3.0    gray            NaN          NaN                     NaN
# 4            3.0    blue            NaN          NaN                     NaN
# 5            3.0    gray        Germany          Yes              15/03/2016
# 6            2.0   black        Germany          NaN              25/02/2021
# 7            3.0   white         Poland          Yes                     NaN
# 8            3.0    blue            NaN          NaN                     NaN
# 9            3.0    gray            NaN          NaN                     NaN
# 10           3.0   white         Poland          NaN                     NaN
# 11           3.0   white            NaN          NaN              29/04/2010
# 12           3.0   black        Germany          NaN              09/11/2017
# 13           3.0    gray            NaN          Yes                     NaN
# 14           3.0     red         Poland          NaN              18/05/2015
# 15           3.0   black         Poland          NaN              27/04/2012
# 16           3.0     red            NaN          NaN                     NaN
# 17           3.0    blue            NaN          NaN                     NaN
# 18           2.0  yellow         Poland          Yes                     NaN
# 19           3.0   white        Germany          NaN              29/05/2009
#
#    Offer_publication_date                                     Offer_location  \
# 0              04/05/2021  ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 1              03/05/2021  kanonierska12 - 04-425 Warszawa, Rembertów (Po...
# 2              03/05/2021                   Warszawa, Mazowieckie, Białołęka
# 3              30/04/2021                                  Jaworzno, Śląskie
# 4              30/04/2021  ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# 5              30/04/2021  Modlińska 157 - 03-186 Warszawa, Białołęka (Po...
# 6              29/04/2021                             Żary, żarski, Lubuskie
# 7              29/04/2021     Ojcowska 2 - 02-918 Warszawa, Mokotów (Polska)
# 8              03/05/2021  ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# 9              03/05/2021  ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# 10             25/04/2021                     Gdańsk, Pomorskie, Śródmieście
# 11             25/04/2021                             Bielsko-Biała, Śląskie
# 12             04/05/2021                              Rzeszów, Podkarpackie
# 13             04/05/2021                  Sulechów, zielonogórski, Lubuskie
# 14             04/05/2021                       Koszalin, Zachodniopomorskie
# 15             23/04/2021               Zgorzelec, zgorzelecki, Dolnośląskie
# 16             29/04/2021  ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 17             29/04/2021  ul. Karkonoska 45 - 53-015 Wrocław, Dolnośląsk...
# 18             04/05/2021                                  Lublin, Lubelskie
# 19             04/05/2021                 Jarocin, jarociński, Wielkopolskie
#
#                                              Features       date  \
# 0                                                  [] 2021-05-04
# 1                                                  [] 2021-05-03
# 2   ['ABS', 'Electric front windows', 'Drivers air... 2021-05-03
# 3   ['ABS', 'Electric front windows', 'Drivers air... 2021-04-30
# 4   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-04-30
# 5   ['ABS', 'Electric front windows', 'Drivers air... 2021-04-30
# 6                                                  [] 2021-04-29
# 7   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-04-29
# 8   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-05-03
# 9   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-05-03
# 10  ['ABS', 'Electric front windows', 'Passengers ... 2021-04-25
# 11  ['ABS', 'Electric front windows', 'Drivers air... 2021-04-25
# 12  ['ABS', 'Immobilizer', 'Factory radio', 'ASR (... 2021-05-04
# 13  ['ABS', 'Bluetooth', 'Rain sensor', 'Panoramic... 2021-05-04
# 14  ['ABS', 'Electric front windows', 'Drivers air... 2021-05-04
# 15  ['ABS', 'Electric front windows', 'Power steer... 2021-04-23
# 16                                                 [] 2021-04-29
# 17  ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-04-29
# 18  ['ABS', 'Electric front windows', 'Drivers air... 2021-05-04
# 19  ['ABS', 'Electric front windows', 'Drivers air... 2021-05-04
#
#    Offer_publication_date_as_date
# 0                      2021-05-04
# 1                      2021-05-03
# 2                      2021-05-03
# 3                      2021-04-30
# 4                      2021-04-30
# 5                      2021-04-30
# 6                      2021-04-29
# 7                      2021-04-29
# 8                      2021-05-03
# 9                      2021-05-03
# 10                     2021-04-25
# 11                     2021-04-25
# 12                     2021-05-04
# 13                     2021-05-04
# 14                     2021-05-04
# 15                     2021-04-23
# 16                     2021-04-29
# 17                     2021-04-29
# 18                     2021-05-04
# 19                     2021-05-04
#
# [20 rows x 27 columns]

# %%
df["Offer_publication_date_as_date"] = pd.to_datetime(df['Offer_publication_date'], dayfirst=True)
df["First_registration_date_as_date"] = pd.to_datetime(df['First_registration_date'], dayfirst=True, errors='coerce')
df = df.drop(columns=['Offer_publication_date', 'First_registration_date'])

df.head(20)
# Out:
#     Index   Price Currency Condition Vehicle_brand Vehicle_model  \
# 0       0   86200      PLN       New        Abarth           595
# 1       1   43500      PLN      Used        Abarth         Other
# 2       2   44900      PLN      Used        Abarth           500
# 3       3   39900      PLN      Used        Abarth           500
# 4       4   97900      PLN       New        Abarth           595
# 5       5   62950      PLN      Used        Abarth           595
# 6       6   69900      PLN      Used        Abarth           595
# 7       7   69900      PLN      Used        Abarth           500
# 8       8  120750      PLN       New        Abarth           595
# 9       9   93100      PLN       New        Abarth           595
# 10     10   67000      PLN      Used        Abarth           595
# 11     11   31900      PLN      Used        Abarth  Grande Punto
# 12     12   70000      PLN      Used        Abarth           595
# 13     13   38500      PLN      Used        Abarth           500
# 14     14   41400      PLN      Used        Abarth           500
# 15     15   36000      PLN      Used        Abarth         Other
# 16     16   80900      PLN       New        Abarth           595
# 17     17  127921      PLN       New        Abarth           595
# 18     18   70900      PLN      Used        Abarth           595
# 19     19   22900      PLN      Used        Abarth  Grande Punto
#
#    Vehicle_version  Vehicle_generation  Production_year  Mileage_km  ...  \
# 0              NaN                 NaN             2021         1.0  ...
# 1              NaN                 NaN             1974     59000.0  ...
# 2              NaN                 NaN             2018     52000.0  ...
# 3              NaN                 NaN             2012     29000.0  ...
# 4              NaN                 NaN             2021       600.0  ...
# 5              NaN                 NaN             2016     46060.0  ...
# 6              NaN                 NaN             2021      2900.0  ...
# 7              NaN                 NaN             2019     20000.0  ...
# 8              NaN                 NaN             2021         1.0  ...
# 9              NaN                 NaN             2021         1.0  ...
# 10             NaN                 NaN             2018     38000.0  ...
# 11             NaN                 NaN             2010    179000.0  ...
# 12             NaN                 NaN             2017     18470.0  ...
# 13             NaN                 NaN             2015    117000.0  ...
# 14             NaN                 NaN             2014     79233.0  ...
# 15             NaN                 NaN             2012     82000.0  ...
# 16             NaN                 NaN             2020         1.0  ...
# 17             NaN                 NaN             2021         3.0  ...
# 18             NaN                 NaN             2019     11000.0  ...
# 19             NaN                 NaN             2009    182000.0  ...
#
#           Type  Doors_number  Colour  Origin_country First_owner  \
# 0   small_cars           3.0    gray             NaN         NaN
# 1        coupe           2.0  silver             NaN         NaN
# 2   small_cars           3.0  silver             NaN         NaN
# 3   small_cars           3.0    gray             NaN         NaN
# 4   small_cars           3.0    blue             NaN         NaN
# 5   small_cars           3.0    gray         Germany         Yes
# 6   small_cars           2.0   black         Germany         NaN
# 7   small_cars           3.0   white          Poland         Yes
# 8   small_cars           3.0    blue             NaN         NaN
# 9   small_cars           3.0    gray             NaN         NaN
# 10  small_cars           3.0   white          Poland         NaN
# 11   city_cars           3.0   white             NaN         NaN
# 12  small_cars           3.0   black         Germany         NaN
# 13   city_cars           3.0    gray             NaN         Yes
# 14  small_cars           3.0     red          Poland         NaN
# 15   city_cars           3.0   black          Poland         NaN
# 16  small_cars           3.0     red             NaN         NaN
# 17  small_cars           3.0    blue             NaN         NaN
# 18  small_cars           2.0  yellow          Poland         Yes
# 19   city_cars           3.0   white         Germany         NaN
#
#                                        Offer_location  \
# 0   ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 1   kanonierska12 - 04-425 Warszawa, Rembertów (Po...
# 2                    Warszawa, Mazowieckie, Białołęka
# 3                                   Jaworzno, Śląskie
# 4   ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# 5   Modlińska 157 - 03-186 Warszawa, Białołęka (Po...
# 6                              Żary, żarski, Lubuskie
# 7      Ojcowska 2 - 02-918 Warszawa, Mokotów (Polska)
# 8   ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# 9   ul. Gorzysława 9 - 61-057 Poznań, Nowe Miasto ...
# 10                     Gdańsk, Pomorskie, Śródmieście
# 11                             Bielsko-Biała, Śląskie
# 12                              Rzeszów, Podkarpackie
# 13                  Sulechów, zielonogórski, Lubuskie
# 14                       Koszalin, Zachodniopomorskie
# 15               Zgorzelec, zgorzelecki, Dolnośląskie
# 16  ul. Jubilerska 6 - 04-190 Warszawa, Mazowiecki...
# 17  ul. Karkonoska 45 - 53-015 Wrocław, Dolnośląsk...
# 18                                  Lublin, Lubelskie
# 19                 Jarocin, jarociński, Wielkopolskie
#
#                                              Features       date  \
# 0                                                  [] 2021-05-04
# 1                                                  [] 2021-05-03
# 2   ['ABS', 'Electric front windows', 'Drivers air... 2021-05-03
# 3   ['ABS', 'Electric front windows', 'Drivers air... 2021-04-30
# 4   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-04-30
# 5   ['ABS', 'Electric front windows', 'Drivers air... 2021-04-30
# 6                                                  [] 2021-04-29
# 7   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-04-29
# 8   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-05-03
# 9   ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-05-03
# 10  ['ABS', 'Electric front windows', 'Passengers ... 2021-04-25
# 11  ['ABS', 'Electric front windows', 'Drivers air... 2021-04-25
# 12  ['ABS', 'Immobilizer', 'Factory radio', 'ASR (... 2021-05-04
# 13  ['ABS', 'Bluetooth', 'Rain sensor', 'Panoramic... 2021-05-04
# 14  ['ABS', 'Electric front windows', 'Drivers air... 2021-05-04
# 15  ['ABS', 'Electric front windows', 'Power steer... 2021-04-23
# 16                                                 [] 2021-04-29
# 17  ['ABS', 'Electrically adjustable mirrors', 'Pa... 2021-04-29
# 18  ['ABS', 'Electric front windows', 'Drivers air... 2021-05-04
# 19  ['ABS', 'Electric front windows', 'Drivers air... 2021-05-04
#
#    Offer_publication_date_as_date First_registration_date_as_date
# 0                      2021-05-04                             NaT
# 1                      2021-05-03                             NaT
# 2                      2021-05-03                             NaT
# 3                      2021-04-30                             NaT
# 4                      2021-04-30                             NaT
# 5                      2021-04-30                      2016-03-15
# 6                      2021-04-29                      2021-02-25
# 7                      2021-04-29                             NaT
# 8                      2021-05-03                             NaT
# 9                      2021-05-03                             NaT
# 10                     2021-04-25                             NaT
# 11                     2021-04-25                      2010-04-29
# 12                     2021-05-04                      2017-11-09
# 13                     2021-05-04                             NaT
# 14                     2021-05-04                      2015-05-18
# 15                     2021-04-23                      2012-04-27
# 16                     2021-04-29                             NaT
# 17                     2021-04-29                             NaT
# 18                     2021-05-04                             NaT
# 19                     2021-05-04                      2009-05-29
#
# [20 rows x 26 columns]
